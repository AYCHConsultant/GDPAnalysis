# %%
# importing required modules
import pandas as pd
import matplotlib.pyplot as plt

#getting all states data

#state-1 Andhra_Pradesh
df_Andhra_Pradesh = pd.read_csv('/DataSet2/Andhra_Pradesh.csv')
df1 = df_Andhra_Pradesh[['Item','2014-15']]
df1.insert(2,'State','Andhra_Pradesh')

#state-2 Andhra_Pradesh
df_Arunachal_Pradesh = pd.read_csv('/DataSet2/Arunachal_Pradesh.csv')
df2 = df_Arunachal_Pradesh[['Item','2014-15']]
df2.insert(2,'State','Arunachal_Pradesh')

#state-3 Assam
df_Assam = pd.read_csv('/DataSet2/Assam.csv')
df3 = df_Assam[['Item','2014-15']]
df3.insert(2,'State','Assam')

#state-4 Bihar
df_Bihar = pd.read_csv('/DataSet2/Bihar.csv')
df4 = df_Bihar[['Item','2014-15']]
df4.insert(2,'State','Bihar')

#state-5 Chhattisgarh
df_Chhattisgarh = pd.read_csv('/Dataset2/Chhattisgarh.csv')
df5 = df_Chhattisgarh[['Item','2014-15']]
df5.insert(2,'State','Chhattisgarh')

#state-6 Goa
df_Goa = pd.read_csv('/DataSet2/Goa.csv')
df6 = df_Goa[['Item','2014-15']]
df6.insert(2,'State','Goa')

#state-7 Gujarat
df_Gujarat = pd.read_csv('/DataSet2/Gujarat.csv')
df7 = df_Gujarat[['Item','2014-15']]
df7.insert(2,'State','Gujarat')

#state-8 Haryana
df_Haryana = pd.read_csv('/DataSet2/Haryana.csv')
df8 = df_Haryana[['Item','2014-15']]
df8.insert(2,'State','Haryana')

#state-9 Himachal_Pradesh
df_Himachal_Pradesh = pd.read_csv('/Dataset2/Himachal_Pradesh.csv')
df9 = df_Himachal_Pradesh[['Item','2014-15']]
df9.insert(2,'State','Himachal_Pradesh')

#state-10 Jammu_Kashmir
df_Jammu_Kashmir = pd.read_csv('/Dataset2/Jammu_Kashmir.csv')
df10 = df_Jammu_Kashmir[['Item','2014-15']]
df10.insert(2,'State','Jammu_Kashmir')

#state-11 Jharkhand
df_Jharkhand = pd.read_csv('/DataSet2/Jharkhand.csv')
df11 = df_Jharkhand[['Item','2014-15']]
df11.insert(2,'State','Jharkhand')

#state-12 Karnataka
df_Karnataka = pd.read_csv('/DataSet2/Karnataka.csv')
df12 = df_Karnataka[['Item','2014-15']]
df12.insert(2,'State','Karnataka')

#state-13 Kerala
df_Kerala = pd.read_csv('/DataSet2/Kerala.csv')
df13 = df_Kerala[['Item','2014-15']]
df13.insert(2,'State','Kerala')

#state-14 Madhya_Pradesh
df_Madhya_Pradesh = pd.read_csv('/DataSet2/Madhya_Pradesh.csv')
df14 = df_Madhya_Pradesh[['Item','2014-15']]
df14.insert(2,'State','Madhya_Pradesh')

#state-15 Maharashtra
df_Maharashtra = pd.read_csv('/DataSet2/Maharashtra.csv')
df15 = df_Maharashtra[['Item','2014-15']]
df15.insert(2,'State','Maharashtra')

#state-16 Manipur
df_Manipur = pd.read_csv('/DataSet2/Manipur.csv')
df16 = df_Manipur[['Item','2014-15']]
df16.insert(2,'State','Manipur')

#state-17 Meghalaya
df_Meghalaya = pd.read_csv('/DataSet2/Meghalaya.csv')
df17 = df_Meghalaya[['Item','2014-15']]
df17.insert(2,'State','Meghalaya')

#state-18 Mizoram
df_Mizoram = pd.read_csv('/DataSet2/Mizoram.csv')
df18 = df_Mizoram[['Item','2014-15']]
df18.insert(2,'State','Mizoram')

#state-19 Nagaland
df_Nagaland = pd.read_csv('/DataSet2/Nagaland.csv')
df19 = df_Nagaland[['Item','2014-15']]
df19.insert(2,'State','Nagaland')

#state-20 Odisha
df_Odisha = pd.read_csv('/DataSet2/Odisha.csv')
df20 = df_Odisha[['Item','2014-15']]
df20.insert(2,'State','Odisha')

#state-21 Punjab
df_Punjab = pd.read_csv('/DataSet2/Punjab.csv')
df21 = df_Punjab[['Item','2014-15']]
df21.insert(2,'State','Punjab')

#state-22 Rajasthan
df_Rajasthan = pd.read_csv('/DataSet2/Rajasthan.csv')
df22 = df_Rajasthan[['Item','2014-15']]
df22.insert(2,'State','Rajasthan')

#state-23 Sikkim
df_Sikkim = pd.read_csv('/DataSet2/Sikkim.csv')
df23 = df_Sikkim[['Item','2014-15']]
df23.insert(2,'State','Sikkim')

#state-24 Tamil_Nadu
df_Tamil_Nadu = pd.read_csv('/DataSet2/Tamil_Nadu.csv')
df24 = df_Tamil_Nadu[['Item','2014-15']]
df24.insert(2,'State','Tamil_Nadu')

#state-25 Telangana
df_Telangana = pd.read_csv('/DataSet2/Telangana.csv')
df25 = df_Telangana[['Item','2014-15']]
df25.insert(2,'State','Telangana')

#state-26 Tripura
df_Tripura = pd.read_csv('/DataSet2/Tripura.csv')
df26 = df_Tripura[['Item','2014-15']]
df26.insert(2,'State','Tripura')

#state-27 Uttar_Pradesh
df_Uttar_Pradesh = pd.read_csv('/DataSet2/Uttar_Pradesh.csv')
df27 = df_Uttar_Pradesh[['Item','2014-15']]
df27.insert(2,'State','Uttar_Pradesh')

#state-28 Uttarakhand
df_Uttarakhand = pd.read_csv('/DataSet2/Uttarakhand.csv')
df28 = df_Uttarakhand[['Item','2014-15']]
df28.insert(2,'State','Uttarakhand')

# %%
frames = [df1.loc[df1['Item'] == 'Per Capita GSDP (Rs.)'], 
          df2.loc[df2['Item'] == 'Per Capita GSDP (Rs.)'], 
          df3.loc[df3['Item'] == 'Per Capita GSDP (Rs.)'], 
          df4.loc[df4['Item'] == 'Per Capita GSDP (Rs.)'], 
          df5.loc[df5['Item'] == 'Per Capita GSDP (Rs.)'],
          df6.loc[df6['Item'] == 'Per Capita GSDP (Rs.)'], 
          df7.loc[df7['Item'] == 'Per Capita GSDP (Rs.)'], 
          df8.loc[df8['Item'] == 'Per Capita GSDP (Rs.)'], 
          df9.loc[df9['Item'] == 'Per Capita GSDP (Rs.)'], 
          df10.loc[df10['Item'] == 'Per Capita GSDP (Rs.)'], 
          df11.loc[df11['Item'] == 'Per Capita GSDP (Rs.)'], 
          df12.loc[df12['Item'] == 'Per Capita GSDP (Rs.)'],
          df13.loc[df13['Item'] == 'Per Capita GSDP (Rs.)'],
          df14.loc[df14['Item'] == 'Per Capita GSDP (Rs.)'],
          df15.loc[df15['Item'] == 'Per Capita GSDP (Rs.)'],
          df16.loc[df16['Item'] == 'Per Capita GSDP (Rs.)'],
          df17.loc[df17['Item'] == 'Per Capita GSDP (Rs.)'],
          df18.loc[df18['Item'] == 'Per Capita GSDP (Rs.)'],
          df19.loc[df19['Item'] == 'Per Capita GSDP (Rs.)'],
          df20.loc[df20['Item'] == 'Per Capita GSDP (Rs.)'], 
          df21.loc[df21['Item'] == 'Per Capita GSDP (Rs.)'], 
          df22.loc[df22['Item'] == 'Per Capita GSDP (Rs.)'], 
          df23.loc[df23['Item'] == 'Per Capita GSDP (Rs.)'], 
          df24.loc[df24['Item'] == 'Per Capita GSDP (Rs.)'], 
          df25.loc[df25['Item'] == 'Per Capita GSDP (Rs.)'], 
          df26.loc[df26['Item'] == 'Per Capita GSDP (Rs.)'], 
          df27.loc[df27['Item'] == 'Per Capita GSDP (Rs.)'], 
          df28.loc[df28['Item'] == 'Per Capita GSDP (Rs.)']]
df_keys = pd.concat(frames)
df_keys = df_keys.sort_values(by=['2014-15'])
df_keys
# Out:
#                      Item   2014-15              State
# 32  Per Capita GSDP (Rs.)   33954.0              Bihar
# 32  Per Capita GSDP (Rs.)   49450.0      Uttar_Pradesh
# 32  Per Capita GSDP (Rs.)   58442.0            Manipur
# 32  Per Capita GSDP (Rs.)   60621.0              Assam
# 32  Per Capita GSDP (Rs.)   62091.0          Jharkhand
# 32  Per Capita GSDP (Rs.)   62989.0     Madhya_Pradesh
# 32  Per Capita GSDP (Rs.)   73979.0             Odisha
# 32  Per Capita GSDP (Rs.)   75840.0      Jammu_Kashmir
# 32  Per Capita GSDP (Rs.)   76228.0          Meghalaya
# 32  Per Capita GSDP (Rs.)   77358.0            Tripura
# 32  Per Capita GSDP (Rs.)   84837.0          Rajasthan
# 32  Per Capita GSDP (Rs.)   86860.0       Chhattisgarh
# 32  Per Capita GSDP (Rs.)   89607.0           Nagaland
# 32  Per Capita GSDP (Rs.)   97687.0            Mizoram
# 32  Per Capita GSDP (Rs.)  104977.0     Andhra_Pradesh
# 32  Per Capita GSDP (Rs.)  112718.0  Arunachal_Pradesh
# ...

# %%
# Plot for total GDP of the states for the year 2014-15
gdp_plot = df_keys['2014-15'].dropna().plot(kind='bar', legend=True, figsize=(16,10))
gdp_plot.set_ylabel('total GDP')
gdp_plot.set_xlabel('States')
gdp_plot.set_title('total GDP of the states for the year 2014-15')
# Out:
# Text(0.5,1,'total GDP of the states for the year 2014-15')

# %%
## Identify the top-5 and the bottom-5 states based on total GDP
## Top 5 States

print("---------------------- TOP 5 States----------------------")
print(df_keys.dropna().tail())
print("--------------------------------------------------------")

## bottom 5 States

print("--------------------- BOTTOM 5 States--------------------")
print(df_keys.dropna().head())
print("--------------------------------------------------------")
# Out:
# ---------------------- TOP 5 States----------------------
#                      Item   2014-15        State
# 32  Per Capita GSDP (Rs.)  153076.0  Uttarakhand
# 32  Per Capita GSDP (Rs.)  154778.0       Kerala
# 32  Per Capita GSDP (Rs.)  164077.0      Haryana
# 32  Per Capita GSDP (Rs.)  240274.0       Sikkim
# 32  Per Capita GSDP (Rs.)  271793.0          Goa
# --------------------------------------------------------
# --------------------- BOTTOM 5 States--------------------
#                      Item  2014-15          State
# 32  Per Capita GSDP (Rs.)  33954.0          Bihar
# 32  Per Capita GSDP (Rs.)  49450.0  Uttar_Pradesh
# 32  Per Capita GSDP (Rs.)  58442.0        Manipur
# 32  Per Capita GSDP (Rs.)  60621.0          Assam
# 32  Per Capita GSDP (Rs.)  62091.0      Jharkhand
# --------------------------------------------------------

# %%
df_keys['2014-15'].max()
# Out:
# 271793.0

# %%
df_keys['2014-15'].min()
# Out:
# 33954.0

# %%
ratio = int(df_keys['2014-15'].max()/df_keys['2014-15'].min())
ratio  
print("--------------- Ratio of highest per capita GDP to the lowest per capita GDP -------------")
print("Highest per capita GDP = "+str(df_keys['2014-15'].max())+" Lowest per capita GDP = "+str(df_keys['2014-15'].min())+" Ratio = "+str(ratio))
# Out:
# --------------- Ratio of highest per capita GDP to the lowest per capita GDP -------------
# Highest per capita GDP = 271793.0 Lowest per capita GDP = 33954.0 Ratio = 8

# %%
primary = [df1.loc[df1['Item'] == 'Primary'].at[6,'2014-15'], 
          df2.loc[df2['Item'] == 'Primary'].at[6,'2014-15'], 
          df3.loc[df3['Item'] == 'Primary'].at[6,'2014-15'], 
          df4.loc[df4['Item'] == 'Primary'].at[6,'2014-15'], 
          df5.loc[df5['Item'] == 'Primary'].at[6,'2014-15'],
          df6.loc[df6['Item'] == 'Primary'].at[6,'2014-15'], 
          df7.loc[df7['Item'] == 'Primary'].at[6,'2014-15'], 
          df8.loc[df8['Item'] == 'Primary'].at[6,'2014-15'], 
          df9.loc[df9['Item'] == 'Primary'].at[6,'2014-15'], 
          df10.loc[df10['Item'] == 'Primary'].at[6,'2014-15'], 
          df11.loc[df11['Item'] == 'Primary'].at[6,'2014-15'], 
          df12.loc[df12['Item'] == 'Primary'].at[6,'2014-15'],
          df13.loc[df13['Item'] == 'Primary'].at[6,'2014-15'],
          df14.loc[df14['Item'] == 'Primary'].at[6,'2014-15'],
          df15.loc[df15['Item'] == 'Primary'].at[6,'2014-15'],
          df16.loc[df16['Item'] == 'Primary'].at[6,'2014-15'],
          df17.loc[df17['Item'] == 'Primary'].at[6,'2014-15'],
          df18.loc[df18['Item'] == 'Primary'].at[6,'2014-15'],
          df19.loc[df19['Item'] == 'Primary'].at[6,'2014-15'],
          df20.loc[df20['Item'] == 'Primary'].at[6,'2014-15'], 
          df21.loc[df21['Item'] == 'Primary'].at[6,'2014-15'], 
          df22.loc[df22['Item'] == 'Primary'].at[6,'2014-15'], 
          df23.loc[df23['Item'] == 'Primary'].at[6,'2014-15'], 
          df24.loc[df24['Item'] == 'Primary'].at[6,'2014-15'], 
          df25.loc[df25['Item'] == 'Primary'].at[6,'2014-15'], 
          df26.loc[df26['Item'] == 'Primary'].at[6,'2014-15'], 
          df27.loc[df27['Item'] == 'Primary'].at[6,'2014-15'], 
          df28.loc[df28['Item'] == 'Primary'].at[6,'2014-15']]
n = len(primary) 
def _sum(arr,n): 
    # return sum using sum  
    # inbuilt sum() function 
    return(sum(arr)) 
primary_sum = _sum(primary,n) 
primary_sum
# Out:
# 218077590.0

# %%
secondary = [df1.loc[df1['Item'] == 'Secondary'].at[10,'2014-15'], 
          df2.loc[df2['Item'] == 'Secondary'].at[10,'2014-15'], 
          df3.loc[df3['Item'] == 'Secondary'].at[10,'2014-15'], 
          df4.loc[df4['Item'] == 'Secondary'].at[10,'2014-15'], 
          df5.loc[df5['Item'] == 'Secondary'].at[10,'2014-15'],
          df6.loc[df6['Item'] == 'Secondary'].at[10,'2014-15'], 
          df7.loc[df7['Item'] == 'Secondary'].at[10,'2014-15'], 
          df8.loc[df8['Item'] == 'Secondary'].at[10,'2014-15'], 
          df9.loc[df9['Item'] == 'Secondary'].at[10,'2014-15'], 
          df10.loc[df10['Item'] == 'Secondary'].at[10,'2014-15'], 
          df11.loc[df11['Item'] == 'Secondary'].at[10,'2014-15'], 
          df12.loc[df12['Item'] == 'Secondary'].at[10,'2014-15'],
          df13.loc[df13['Item'] == 'Secondary'].at[10,'2014-15'],
          df14.loc[df14['Item'] == 'Secondary'].at[10,'2014-15'],
          df15.loc[df15['Item'] == 'Secondary'].at[10,'2014-15'],
          df16.loc[df16['Item'] == 'Secondary'].at[10,'2014-15'],
          df17.loc[df17['Item'] == 'Secondary'].at[10,'2014-15'],
          df18.loc[df18['Item'] == 'Secondary'].at[10,'2014-15'],
          df19.loc[df19['Item'] == 'Secondary'].at[10,'2014-15'],
          df20.loc[df20['Item'] == 'Secondary'].at[10,'2014-15'], 
          df21.loc[df21['Item'] == 'Secondary'].at[10,'2014-15'], 
          df22.loc[df22['Item'] == 'Secondary'].at[10,'2014-15'], 
          df23.loc[df23['Item'] == 'Secondary'].at[10,'2014-15'], 
          df24.loc[df24['Item'] == 'Secondary'].at[10,'2014-15'], 
          df25.loc[df25['Item'] == 'Secondary'].at[10,'2014-15'], 
          df26.loc[df26['Item'] == 'Secondary'].at[10,'2014-15'], 
          df27.loc[df27['Item'] == 'Secondary'].at[10,'2014-15'], 
          df28.loc[df28['Item'] == 'Secondary'].at[10,'2014-15']]
n = len(secondary) 
def _sum(arr,n): 
    # return sum using sum  
    # inbuilt sum() function 
    return(sum(arr)) 
secondary_sum = _sum(secondary,n) 
secondary_sum
# Out:
# 287398113.0

# %%
tertiary = [df1.loc[df1['Item'] == 'Tertiary'].at[26,'2014-15'], 
          df2.loc[df2['Item'] == 'Tertiary'].at[26,'2014-15'], 
          df3.loc[df3['Item'] == 'Tertiary'].at[26,'2014-15'], 
          df4.loc[df4['Item'] == 'Tertiary'].at[26,'2014-15'], 
          df5.loc[df5['Item'] == 'Tertiary'].at[26,'2014-15'],
          df6.loc[df6['Item'] == 'Tertiary'].at[26,'2014-15'], 
          df7.loc[df7['Item'] == 'Tertiary'].at[26,'2014-15'], 
          df8.loc[df8['Item'] == 'Tertiary'].at[26,'2014-15'], 
          df9.loc[df9['Item'] == 'Tertiary'].at[26,'2014-15'], 
          df10.loc[df10['Item'] == 'Tertiary'].at[26,'2014-15'], 
          df11.loc[df11['Item'] == 'Tertiary'].at[26,'2014-15'], 
          df12.loc[df12['Item'] == 'Tertiary'].at[26,'2014-15'],
          df13.loc[df13['Item'] == 'Tertiary'].at[26,'2014-15'],
          df14.loc[df14['Item'] == 'Tertiary'].at[26,'2014-15'],
          df15.loc[df15['Item'] == 'Tertiary'].at[26,'2014-15'],
          df16.loc[df16['Item'] == 'Tertiary'].at[26,'2014-15'],
          df17.loc[df17['Item'] == 'Tertiary'].at[26,'2014-15'],
          df18.loc[df18['Item'] == 'Tertiary'].at[26,'2014-15'],
          df19.loc[df19['Item'] == 'Tertiary'].at[26,'2014-15'],
          df20.loc[df20['Item'] == 'Tertiary'].at[26,'2014-15'], 
          df21.loc[df21['Item'] == 'Tertiary'].at[26,'2014-15'], 
          df22.loc[df22['Item'] == 'Tertiary'].at[26,'2014-15'], 
          df23.loc[df23['Item'] == 'Tertiary'].at[26,'2014-15'], 
          df24.loc[df24['Item'] == 'Tertiary'].at[26,'2014-15'], 
          df25.loc[df25['Item'] == 'Tertiary'].at[26,'2014-15'], 
          df26.loc[df26['Item'] == 'Tertiary'].at[26,'2014-15'], 
          df27.loc[df27['Item'] == 'Tertiary'].at[26,'2014-15'], 
          df28.loc[df28['Item'] == 'Tertiary'].at[26,'2014-15']]
n = len(tertiary) 
def _sum(arr,n): 
    # return sum using sum  
    # inbuilt sum() function 
    return(sum(arr)) 
tertiary_sum = _sum(tertiary,n)
tertiary_sum
# Out:
# 512056980.0

# %%
# Data to plot
labels = 'Primary', 'Secondary','Tertiary'
sizes = [primary_sum, secondary_sum, tertiary_sum]
colors = ['gold', 'lightcoral', 'lightskyblue']
explode = (0.1, 0, 0)  # explode 1st slice

# Plot
plt.pie(sizes, explode=explode, labels=labels, colors=colors,
autopct='%1.1f%%', shadow=True, startangle=90)

plt.axis('equal')
plt.show()

# %%
df_quatile = df_keys.quantile([0,0.20,0.5,0.85,1],axis=0)
df_quatile
# Out:
#         2014-15
# 0.00   33954.00
# 0.20   67385.00
# 0.50  101332.00
# 0.85  153064.85
# 1.00  271793.00

# %%
df_keys['Category'] = pd.qcut(df_keys['2014-15'],q=[0,0.20,0.5,0.85,1],labels=["c4","c3","c2","c1"])
df_keys = df_keys.sort_values(by=['2014-15'])
df_keys
# Out:
#                      Item   2014-15              State Category
# 32  Per Capita GSDP (Rs.)   33954.0              Bihar       c4
# 32  Per Capita GSDP (Rs.)   49450.0      Uttar_Pradesh       c4
# 32  Per Capita GSDP (Rs.)   58442.0            Manipur       c4
# 32  Per Capita GSDP (Rs.)   60621.0              Assam       c4
# 32  Per Capita GSDP (Rs.)   62091.0          Jharkhand       c4
# 32  Per Capita GSDP (Rs.)   62989.0     Madhya_Pradesh       c4
# 32  Per Capita GSDP (Rs.)   73979.0             Odisha       c3
# 32  Per Capita GSDP (Rs.)   75840.0      Jammu_Kashmir       c3
# 32  Per Capita GSDP (Rs.)   76228.0          Meghalaya       c3
# 32  Per Capita GSDP (Rs.)   77358.0            Tripura       c3
# 32  Per Capita GSDP (Rs.)   84837.0          Rajasthan       c3
# 32  Per Capita GSDP (Rs.)   86860.0       Chhattisgarh       c3
# 32  Per Capita GSDP (Rs.)   89607.0           Nagaland       c3
# 32  Per Capita GSDP (Rs.)   97687.0            Mizoram       c3
# ...
